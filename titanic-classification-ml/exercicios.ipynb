# %% [markdown]
# ### 1. Carregue o dataset disponível em "https://github.com/cassiusf/datasets/raw/refs/heads/main/titanic_data.csv" para um dataframe utilizando linguagem Python e execute as seguintes transformações, utilizando a biblioteca Pandas:
#
# * Elimine as variáveis “PassengerId”, “Name”, “Ticket” e “Cabin”;
# * Elimine observações que contenham dados ausentes (NA);
# * Aplique o LabelEncoder nas variáveis “Embarked” e “Sex”;
# * Separe o dataframe resultante em Treino-Teste, utilizando a proporção 80-20%.

# %% [markdown]
# ## Modelo de Àrvore de Decisão

# %% [markdown]
# ### 2. A partir do dataframe totalmente transformado da questão 1, aplique um modelo de árvore de decisão simples, utilizando os parâmetros default apresentados pela biblioteca Scikit-learn.
# * Apresente a matriz de confusão com o resultado da aplicação do modelo no conjunto de testes.
# * Apresente os valores encontrados para as medidas TN, TP, FN e FP.
# * Apresente a acurácia de seu modelo.
# * Apresente as métricas precision, recall e F1-score do seu modelo.

# %% [markdown]
# ### 3. Experimente duas novas profundidades na execução de sua árvore de decisão e apresente a conclusão do impacto dessas alterações em sua árvore, a partir das novas métricas alcançadas.

# %% [markdown]
# ### 4. Apresente as visualizações da árvore original e das duas árvores criadas na questão 3.

# %% [markdown]
# ## Modelo SVM

# %% [markdown]
# ### 5. A partir do dataframe totalmente transformado da questão 1, aplique um modelo SVM utilizando um Kernel linear.
# * Apresente a matriz de confusão resultante do processo de treinamento.
# * Apresente as métricas acurácia, precision, recall e F1-score deste modelo.

# %% [markdown]
# ### 6. Execute o mesmo modelo, agora utilizando dois núcleos diferentes, o rbf e o sigmoid.
# * Apresente a matriz de confusão resultante do processo de treinamento.
# * Apresente as métricas acurácia, precision, recall e F1-score deste modelo.

# %% [markdown]
# ### 7. Compare as três execuções (kernel linear, rbf e sigmoid), apresente um resumo dos resultados relevantes e indique qual o melhor, a partir do experimento.
